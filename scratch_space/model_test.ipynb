# %%
import requests
import os

def download_pokemon_sprite(pokemon_name_or_id, output_dir=".", file_prefix = None):
    """
    Downloads the front_default sprite for a given pokemon using the PokeAPI.
    
    Args:
        pokemon_name_or_id (str/int): The name or ID of the pokemon (e.g., 'ditto' or 132).
        output_dir (str): Directory to save the image. Defaults to current directory.
    """
    # 1. Fetch pokemon data from the API
    api_url = f"https://pokeapi.co/api/v2/pokemon/{pokemon_name_or_id}"
    print(f"Fetching API data for '{pokemon_name_or_id}' from {api_url}...")
    
    response = requests.get(api_url)
    if response.status_code != 200:
        print(f"Error: Failed to retrieve data. Status code: {response.status_code}")
        return
        
    data = response.json()
    
    # 2. Extract the front_default sprite URL
    sprite_url = data.get("sprites", {}).get("front_default")
    if not sprite_url:
        print(f"Error: No front_default sprite found for '{pokemon_name_or_id}'.")
        return
        
    print(f"Sprite found at: {sprite_url}")
    print("Downloading image...")
    
    # 3. Download the specific image
    img_response = requests.get(sprite_url)
    if img_response.status_code == 200:
        # Make sure output directory exists
        os.makedirs(output_dir, exist_ok=True)
        
        pokemon_name = data.get("name", str(pokemon_name_or_id))
        if file_prefix:
            filename = os.path.join(output_dir, f"{file_prefix}_{pokemon_name}.png")
        else:
            filename = os.path.join(output_dir, f"{pokemon_name}.png")


        
        # Save the image to disk
        with open(filename, 'wb') as f:
            f.write(img_response.content)
            
        print(f"Successfully saved {pokemon_name} sprite to {filename}")
    else:
        print(f"Error: Failed to download the image. Status code: {img_response.status_code}")

# %%
for i in range(1,1026):
    download_pokemon_sprite(i, output_dir="../pokemon_sprites", file_prefix='train')
# Out:
# Fetching API data for '1' from https://pokeapi.co/api/v2/pokemon/1...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/1.png
# Downloading image...
# Successfully saved bulbasaur sprite to ../pokemon_sprites/train_bulbasaur.png
# Fetching API data for '2' from https://pokeapi.co/api/v2/pokemon/2...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/2.png
# Downloading image...
# Successfully saved ivysaur sprite to ../pokemon_sprites/train_ivysaur.png
# Fetching API data for '3' from https://pokeapi.co/api/v2/pokemon/3...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/3.png
# Downloading image...
# Successfully saved venusaur sprite to ../pokemon_sprites/train_venusaur.png
# Fetching API data for '4' from https://pokeapi.co/api/v2/pokemon/4...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/4.png
# Downloading image...
# Successfully saved charmander sprite to ../pokemon_sprites/train_charmander.png
# Fetching API data for '5' from https://pokeapi.co/api/v2/pokemon/5...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/5.png
# Downloading image...
# Successfully saved charmeleon sprite to ../pokemon_sprites/train_charmeleon.png
# Fetching API data for '6' from https://pokeapi.co/api/v2/pokemon/6...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/6.png
# Downloading image...
# Successfully saved charizard sprite to ../pokemon_sprites/train_charizard.png
# Fetching API data for '7' from https://pokeapi.co/api/v2/pokemon/7...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/7.png
# Downloading image...
# Successfully saved squirtle sprite to ../pokemon_sprites/train_squirtle.png
# Fetching API data for '8' from https://pokeapi.co/api/v2/pokemon/8...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/8.png
# Downloading image...
# Successfully saved wartortle sprite to ../pokemon_sprites/train_wartortle.png
# Fetching API data for '9' from https://pokeapi.co/api/v2/pokemon/9...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/9.png
# Downloading image...
# Successfully saved blastoise sprite to ../pokemon_sprites/train_blastoise.png
# Fetching API data for '10' from https://pokeapi.co/api/v2/pokemon/10...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/10.png
# Downloading image...
# Successfully saved caterpie sprite to ../pokemon_sprites/train_caterpie.png
# Fetching API data for '11' from https://pokeapi.co/api/v2/pokemon/11...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/11.png
# Downloading image...
# Successfully saved metapod sprite to ../pokemon_sprites/train_metapod.png
# Fetching API data for '12' from https://pokeapi.co/api/v2/pokemon/12...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/12.png
# Downloading image...
# Successfully saved butterfree sprite to ../pokemon_sprites/train_butterfree.png
# Fetching API data for '13' from https://pokeapi.co/api/v2/pokemon/13...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/13.png
# Downloading image...
# Successfully saved weedle sprite to ../pokemon_sprites/train_weedle.png
# Fetching API data for '14' from https://pokeapi.co/api/v2/pokemon/14...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/14.png
# Downloading image...
# Successfully saved kakuna sprite to ../pokemon_sprites/train_kakuna.png
# Fetching API data for '15' from https://pokeapi.co/api/v2/pokemon/15...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/15.png
# Downloading image...
# Successfully saved beedrill sprite to ../pokemon_sprites/train_beedrill.png
# Fetching API data for '16' from https://pokeapi.co/api/v2/pokemon/16...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/16.png
# Downloading image...
# Successfully saved pidgey sprite to ../pokemon_sprites/train_pidgey.png
# Fetching API data for '17' from https://pokeapi.co/api/v2/pokemon/17...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/17.png
# Downloading image...
# Successfully saved pidgeotto sprite to ../pokemon_sprites/train_pidgeotto.png
# Fetching API data for '18' from https://pokeapi.co/api/v2/pokemon/18...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/18.png
# Downloading image...
# Successfully saved pidgeot sprite to ../pokemon_sprites/train_pidgeot.png
# Fetching API data for '19' from https://pokeapi.co/api/v2/pokemon/19...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/19.png
# Downloading image...
# Successfully saved rattata sprite to ../pokemon_sprites/train_rattata.png
# Fetching API data for '20' from https://pokeapi.co/api/v2/pokemon/20...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/20.png
# Downloading image...
# Successfully saved raticate sprite to ../pokemon_sprites/train_raticate.png
# Fetching API data for '21' from https://pokeapi.co/api/v2/pokemon/21...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/21.png
# Downloading image...
# Successfully saved spearow sprite to ../pokemon_sprites/train_spearow.png
# Fetching API data for '22' from https://pokeapi.co/api/v2/pokemon/22...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/22.png
# Downloading image...
# Successfully saved fearow sprite to ../pokemon_sprites/train_fearow.png
# Fetching API data for '23' from https://pokeapi.co/api/v2/pokemon/23...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/23.png
# Downloading image...
# Successfully saved ekans sprite to ../pokemon_sprites/train_ekans.png
# Fetching API data for '24' from https://pokeapi.co/api/v2/pokemon/24...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/24.png
# Downloading image...
# Successfully saved arbok sprite to ../pokemon_sprites/train_arbok.png
# Fetching API data for '25' from https://pokeapi.co/api/v2/pokemon/25...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/25.png
# Downloading image...
# Successfully saved pikachu sprite to ../pokemon_sprites/train_pikachu.png
# Fetching API data for '26' from https://pokeapi.co/api/v2/pokemon/26...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/26.png
# Downloading image...
# Successfully saved raichu sprite to ../pokemon_sprites/train_raichu.png
# Fetching API data for '27' from https://pokeapi.co/api/v2/pokemon/27...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/27.png
# Downloading image...
# Successfully saved sandshrew sprite to ../pokemon_sprites/train_sandshrew.png
# Fetching API data for '28' from https://pokeapi.co/api/v2/pokemon/28...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/28.png
# Downloading image...
# Successfully saved sandslash sprite to ../pokemon_sprites/train_sandslash.png
# Fetching API data for '29' from https://pokeapi.co/api/v2/pokemon/29...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/29.png
# Downloading image...
# Successfully saved nidoran-f sprite to ../pokemon_sprites/train_nidoran-f.png
# Fetching API data for '30' from https://pokeapi.co/api/v2/pokemon/30...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/30.png
# Downloading image...
# Successfully saved nidorina sprite to ../pokemon_sprites/train_nidorina.png
# Fetching API data for '31' from https://pokeapi.co/api/v2/pokemon/31...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/31.png
# Downloading image...
# Successfully saved nidoqueen sprite to ../pokemon_sprites/train_nidoqueen.png
# Fetching API data for '32' from https://pokeapi.co/api/v2/pokemon/32...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/32.png
# Downloading image...
# Successfully saved nidoran-m sprite to ../pokemon_sprites/train_nidoran-m.png
# Fetching API data for '33' from https://pokeapi.co/api/v2/pokemon/33...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/33.png
# Downloading image...
# Successfully saved nidorino sprite to ../pokemon_sprites/train_nidorino.png
# Fetching API data for '34' from https://pokeapi.co/api/v2/pokemon/34...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/34.png
# Downloading image...
# Successfully saved nidoking sprite to ../pokemon_sprites/train_nidoking.png
# Fetching API data for '35' from https://pokeapi.co/api/v2/pokemon/35...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/35.png
# Downloading image...
# Successfully saved clefairy sprite to ../pokemon_sprites/train_clefairy.png
# Fetching API data for '36' from https://pokeapi.co/api/v2/pokemon/36...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/36.png
# Downloading image...
# Successfully saved clefable sprite to ../pokemon_sprites/train_clefable.png
# Fetching API data for '37' from https://pokeapi.co/api/v2/pokemon/37...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/37.png
# Downloading image...
# Successfully saved vulpix sprite to ../pokemon_sprites/train_vulpix.png
# Fetching API data for '38' from https://pokeapi.co/api/v2/pokemon/38...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/38.png
# Downloading image...
# Successfully saved ninetales sprite to ../pokemon_sprites/train_ninetales.png
# Fetching API data for '39' from https://pokeapi.co/api/v2/pokemon/39...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/39.png
# Downloading image...
# Successfully saved jigglypuff sprite to ../pokemon_sprites/train_jigglypuff.png
# Fetching API data for '40' from https://pokeapi.co/api/v2/pokemon/40...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/40.png
# Downloading image...
# Successfully saved wigglytuff sprite to ../pokemon_sprites/train_wigglytuff.png
# Fetching API data for '41' from https://pokeapi.co/api/v2/pokemon/41...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/41.png
# Downloading image...
# Successfully saved zubat sprite to ../pokemon_sprites/train_zubat.png
# Fetching API data for '42' from https://pokeapi.co/api/v2/pokemon/42...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/42.png
# Downloading image...
# Successfully saved golbat sprite to ../pokemon_sprites/train_golbat.png
# Fetching API data for '43' from https://pokeapi.co/api/v2/pokemon/43...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/43.png
# Downloading image...
# Successfully saved oddish sprite to ../pokemon_sprites/train_oddish.png
# Fetching API data for '44' from https://pokeapi.co/api/v2/pokemon/44...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/44.png
# Downloading image...
# Successfully saved gloom sprite to ../pokemon_sprites/train_gloom.png
# Fetching API data for '45' from https://pokeapi.co/api/v2/pokemon/45...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/45.png
# Downloading image...
# Successfully saved vileplume sprite to ../pokemon_sprites/train_vileplume.png
# Fetching API data for '46' from https://pokeapi.co/api/v2/pokemon/46...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/46.png
# Downloading image...
# Successfully saved paras sprite to ../pokemon_sprites/train_paras.png
# Fetching API data for '47' from https://pokeapi.co/api/v2/pokemon/47...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/47.png
# Downloading image...
# Successfully saved parasect sprite to ../pokemon_sprites/train_parasect.png
# Fetching API data for '48' from https://pokeapi.co/api/v2/pokemon/48...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/48.png
# Downloading image...
# Successfully saved venonat sprite to ../pokemon_sprites/train_venonat.png
# Fetching API data for '49' from https://pokeapi.co/api/v2/pokemon/49...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/49.png
# Downloading image...
# Successfully saved venomoth sprite to ../pokemon_sprites/train_venomoth.png
# Fetching API data for '50' from https://pokeapi.co/api/v2/pokemon/50...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/50.png
# Downloading image...
# Successfully saved diglett sprite to ../pokemon_sprites/train_diglett.png
# Fetching API data for '51' from https://pokeapi.co/api/v2/pokemon/51...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/51.png
# Downloading image...
# Successfully saved dugtrio sprite to ../pokemon_sprites/train_dugtrio.png
# Fetching API data for '52' from https://pokeapi.co/api/v2/pokemon/52...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/52.png
# Downloading image...
# Successfully saved meowth sprite to ../pokemon_sprites/train_meowth.png
# Fetching API data for '53' from https://pokeapi.co/api/v2/pokemon/53...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/53.png
# Downloading image...
# Successfully saved persian sprite to ../pokemon_sprites/train_persian.png
# Fetching API data for '54' from https://pokeapi.co/api/v2/pokemon/54...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/54.png
# Downloading image...
# Successfully saved psyduck sprite to ../pokemon_sprites/train_psyduck.png
# Fetching API data for '55' from https://pokeapi.co/api/v2/pokemon/55...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/55.png
# Downloading image...
# Successfully saved golduck sprite to ../pokemon_sprites/train_golduck.png
# Fetching API data for '56' from https://pokeapi.co/api/v2/pokemon/56...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/56.png
# Downloading image...
# Successfully saved mankey sprite to ../pokemon_sprites/train_mankey.png
# Fetching API data for '57' from https://pokeapi.co/api/v2/pokemon/57...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/57.png
# Downloading image...
# Successfully saved primeape sprite to ../pokemon_sprites/train_primeape.png
# Fetching API data for '58' from https://pokeapi.co/api/v2/pokemon/58...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/58.png
# Downloading image...
# Successfully saved growlithe sprite to ../pokemon_sprites/train_growlithe.png
# Fetching API data for '59' from https://pokeapi.co/api/v2/pokemon/59...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/59.png
# Downloading image...
# Successfully saved arcanine sprite to ../pokemon_sprites/train_arcanine.png
# Fetching API data for '60' from https://pokeapi.co/api/v2/pokemon/60...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/60.png
# Downloading image...
# Successfully saved poliwag sprite to ../pokemon_sprites/train_poliwag.png
# Fetching API data for '61' from https://pokeapi.co/api/v2/pokemon/61...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/61.png
# Downloading image...
# Successfully saved poliwhirl sprite to ../pokemon_sprites/train_poliwhirl.png
# Fetching API data for '62' from https://pokeapi.co/api/v2/pokemon/62...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/62.png
# Downloading image...
# Successfully saved poliwrath sprite to ../pokemon_sprites/train_poliwrath.png
# Fetching API data for '63' from https://pokeapi.co/api/v2/pokemon/63...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/63.png
# Downloading image...
# Successfully saved abra sprite to ../pokemon_sprites/train_abra.png
# Fetching API data for '64' from https://pokeapi.co/api/v2/pokemon/64...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/64.png
# Downloading image...
# Successfully saved kadabra sprite to ../pokemon_sprites/train_kadabra.png
# Fetching API data for '65' from https://pokeapi.co/api/v2/pokemon/65...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/65.png
# Downloading image...
# Successfully saved alakazam sprite to ../pokemon_sprites/train_alakazam.png
# Fetching API data for '66' from https://pokeapi.co/api/v2/pokemon/66...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/66.png
# Downloading image...
# Successfully saved machop sprite to ../pokemon_sprites/train_machop.png
# Fetching API data for '67' from https://pokeapi.co/api/v2/pokemon/67...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/67.png
# Downloading image...
# Successfully saved machoke sprite to ../pokemon_sprites/train_machoke.png
# Fetching API data for '68' from https://pokeapi.co/api/v2/pokemon/68...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/68.png
# Downloading image...
# Successfully saved machamp sprite to ../pokemon_sprites/train_machamp.png
# Fetching API data for '69' from https://pokeapi.co/api/v2/pokemon/69...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/69.png
# Downloading image...
# Successfully saved bellsprout sprite to ../pokemon_sprites/train_bellsprout.png
# Fetching API data for '70' from https://pokeapi.co/api/v2/pokemon/70...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/70.png
# Downloading image...
# Successfully saved weepinbell sprite to ../pokemon_sprites/train_weepinbell.png
# Fetching API data for '71' from https://pokeapi.co/api/v2/pokemon/71...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/71.png
# Downloading image...
# Successfully saved victreebel sprite to ../pokemon_sprites/train_victreebel.png
# Fetching API data for '72' from https://pokeapi.co/api/v2/pokemon/72...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/72.png
# Downloading image...
# Successfully saved tentacool sprite to ../pokemon_sprites/train_tentacool.png
# Fetching API data for '73' from https://pokeapi.co/api/v2/pokemon/73...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/73.png
# Downloading image...
# Successfully saved tentacruel sprite to ../pokemon_sprites/train_tentacruel.png
# Fetching API data for '74' from https://pokeapi.co/api/v2/pokemon/74...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/74.png
# Downloading image...
# Successfully saved geodude sprite to ../pokemon_sprites/train_geodude.png
# Fetching API data for '75' from https://pokeapi.co/api/v2/pokemon/75...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/75.png
# Downloading image...
# Successfully saved graveler sprite to ../pokemon_sprites/train_graveler.png
# Fetching API data for '76' from https://pokeapi.co/api/v2/pokemon/76...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/76.png
# Downloading image...
# Successfully saved golem sprite to ../pokemon_sprites/train_golem.png
# Fetching API data for '77' from https://pokeapi.co/api/v2/pokemon/77...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/77.png
# Downloading image...
# Successfully saved ponyta sprite to ../pokemon_sprites/train_ponyta.png
# Fetching API data for '78' from https://pokeapi.co/api/v2/pokemon/78...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/78.png
# Downloading image...
# Successfully saved rapidash sprite to ../pokemon_sprites/train_rapidash.png
# Fetching API data for '79' from https://pokeapi.co/api/v2/pokemon/79...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/79.png
# Downloading image...
# Successfully saved slowpoke sprite to ../pokemon_sprites/train_slowpoke.png
# Fetching API data for '80' from https://pokeapi.co/api/v2/pokemon/80...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/80.png
# Downloading image...
# Successfully saved slowbro sprite to ../pokemon_sprites/train_slowbro.png
# Fetching API data for '81' from https://pokeapi.co/api/v2/pokemon/81...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/81.png
# Downloading image...
# Successfully saved magnemite sprite to ../pokemon_sprites/train_magnemite.png
# Fetching API data for '82' from https://pokeapi.co/api/v2/pokemon/82...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/82.png
# Downloading image...
# Successfully saved magneton sprite to ../pokemon_sprites/train_magneton.png
# Fetching API data for '83' from https://pokeapi.co/api/v2/pokemon/83...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/83.png
# Downloading image...
# Successfully saved farfetchd sprite to ../pokemon_sprites/train_farfetchd.png
# Fetching API data for '84' from https://pokeapi.co/api/v2/pokemon/84...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/84.png
# Downloading image...
# Successfully saved doduo sprite to ../pokemon_sprites/train_doduo.png
# Fetching API data for '85' from https://pokeapi.co/api/v2/pokemon/85...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/85.png
# Downloading image...
# Successfully saved dodrio sprite to ../pokemon_sprites/train_dodrio.png
# Fetching API data for '86' from https://pokeapi.co/api/v2/pokemon/86...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/86.png
# Downloading image...
# Successfully saved seel sprite to ../pokemon_sprites/train_seel.png
# Fetching API data for '87' from https://pokeapi.co/api/v2/pokemon/87...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/87.png
# Downloading image...
# Successfully saved dewgong sprite to ../pokemon_sprites/train_dewgong.png
# Fetching API data for '88' from https://pokeapi.co/api/v2/pokemon/88...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/88.png
# Downloading image...
# Successfully saved grimer sprite to ../pokemon_sprites/train_grimer.png
# Fetching API data for '89' from https://pokeapi.co/api/v2/pokemon/89...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/89.png
# Downloading image...
# Successfully saved muk sprite to ../pokemon_sprites/train_muk.png
# Fetching API data for '90' from https://pokeapi.co/api/v2/pokemon/90...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/90.png
# Downloading image...
# Successfully saved shellder sprite to ../pokemon_sprites/train_shellder.png
# Fetching API data for '91' from https://pokeapi.co/api/v2/pokemon/91...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/91.png
# Downloading image...
# Successfully saved cloyster sprite to ../pokemon_sprites/train_cloyster.png
# Fetching API data for '92' from https://pokeapi.co/api/v2/pokemon/92...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/92.png
# Downloading image...
# Successfully saved gastly sprite to ../pokemon_sprites/train_gastly.png
# Fetching API data for '93' from https://pokeapi.co/api/v2/pokemon/93...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/93.png
# Downloading image...
# Successfully saved haunter sprite to ../pokemon_sprites/train_haunter.png
# Fetching API data for '94' from https://pokeapi.co/api/v2/pokemon/94...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/94.png
# Downloading image...
# Successfully saved gengar sprite to ../pokemon_sprites/train_gengar.png
# Fetching API data for '95' from https://pokeapi.co/api/v2/pokemon/95...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/95.png
# Downloading image...
# Successfully saved onix sprite to ../pokemon_sprites/train_onix.png
# Fetching API data for '96' from https://pokeapi.co/api/v2/pokemon/96...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/96.png
# Downloading image...
# Successfully saved drowzee sprite to ../pokemon_sprites/train_drowzee.png
# Fetching API data for '97' from https://pokeapi.co/api/v2/pokemon/97...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/97.png
# Downloading image...
# Successfully saved hypno sprite to ../pokemon_sprites/train_hypno.png
# Fetching API data for '98' from https://pokeapi.co/api/v2/pokemon/98...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/98.png
# Downloading image...
# Successfully saved krabby sprite to ../pokemon_sprites/train_krabby.png
# Fetching API data for '99' from https://pokeapi.co/api/v2/pokemon/99...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/99.png
# Downloading image...
# Successfully saved kingler sprite to ../pokemon_sprites/train_kingler.png
# Fetching API data for '100' from https://pokeapi.co/api/v2/pokemon/100...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/100.png
# Downloading image...
# Successfully saved voltorb sprite to ../pokemon_sprites/train_voltorb.png
# Fetching API data for '101' from https://pokeapi.co/api/v2/pokemon/101...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/101.png
# Downloading image...
# Successfully saved electrode sprite to ../pokemon_sprites/train_electrode.png
# Fetching API data for '102' from https://pokeapi.co/api/v2/pokemon/102...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/102.png
# Downloading image...
# Successfully saved exeggcute sprite to ../pokemon_sprites/train_exeggcute.png
# Fetching API data for '103' from https://pokeapi.co/api/v2/pokemon/103...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/103.png
# Downloading image...
# Successfully saved exeggutor sprite to ../pokemon_sprites/train_exeggutor.png
# Fetching API data for '104' from https://pokeapi.co/api/v2/pokemon/104...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/104.png
# Downloading image...
# Successfully saved cubone sprite to ../pokemon_sprites/train_cubone.png
# Fetching API data for '105' from https://pokeapi.co/api/v2/pokemon/105...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/105.png
# Downloading image...
# Successfully saved marowak sprite to ../pokemon_sprites/train_marowak.png
# Fetching API data for '106' from https://pokeapi.co/api/v2/pokemon/106...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/106.png
# Downloading image...
# Successfully saved hitmonlee sprite to ../pokemon_sprites/train_hitmonlee.png
# Fetching API data for '107' from https://pokeapi.co/api/v2/pokemon/107...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/107.png
# Downloading image...
# Successfully saved hitmonchan sprite to ../pokemon_sprites/train_hitmonchan.png
# Fetching API data for '108' from https://pokeapi.co/api/v2/pokemon/108...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/108.png
# Downloading image...
# Successfully saved lickitung sprite to ../pokemon_sprites/train_lickitung.png
# Fetching API data for '109' from https://pokeapi.co/api/v2/pokemon/109...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/109.png
# Downloading image...
# Successfully saved koffing sprite to ../pokemon_sprites/train_koffing.png
# Fetching API data for '110' from https://pokeapi.co/api/v2/pokemon/110...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/110.png
# Downloading image...
# Successfully saved weezing sprite to ../pokemon_sprites/train_weezing.png
# Fetching API data for '111' from https://pokeapi.co/api/v2/pokemon/111...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/111.png
# Downloading image...
# Successfully saved rhyhorn sprite to ../pokemon_sprites/train_rhyhorn.png
# Fetching API data for '112' from https://pokeapi.co/api/v2/pokemon/112...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/112.png
# Downloading image...
# Successfully saved rhydon sprite to ../pokemon_sprites/train_rhydon.png
# Fetching API data for '113' from https://pokeapi.co/api/v2/pokemon/113...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/113.png
# Downloading image...
# Successfully saved chansey sprite to ../pokemon_sprites/train_chansey.png
# Fetching API data for '114' from https://pokeapi.co/api/v2/pokemon/114...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/114.png
# Downloading image...
# Successfully saved tangela sprite to ../pokemon_sprites/train_tangela.png
# Fetching API data for '115' from https://pokeapi.co/api/v2/pokemon/115...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/115.png
# Downloading image...
# Successfully saved kangaskhan sprite to ../pokemon_sprites/train_kangaskhan.png
# Fetching API data for '116' from https://pokeapi.co/api/v2/pokemon/116...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/116.png
# Downloading image...
# Successfully saved horsea sprite to ../pokemon_sprites/train_horsea.png
# Fetching API data for '117' from https://pokeapi.co/api/v2/pokemon/117...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/117.png
# Downloading image...
# Successfully saved seadra sprite to ../pokemon_sprites/train_seadra.png
# Fetching API data for '118' from https://pokeapi.co/api/v2/pokemon/118...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/118.png
# Downloading image...
# Successfully saved goldeen sprite to ../pokemon_sprites/train_goldeen.png
# Fetching API data for '119' from https://pokeapi.co/api/v2/pokemon/119...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/119.png
# Downloading image...
# Successfully saved seaking sprite to ../pokemon_sprites/train_seaking.png
# Fetching API data for '120' from https://pokeapi.co/api/v2/pokemon/120...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/120.png
# Downloading image...
# Successfully saved staryu sprite to ../pokemon_sprites/train_staryu.png
# Fetching API data for '121' from https://pokeapi.co/api/v2/pokemon/121...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/121.png
# Downloading image...
# Successfully saved starmie sprite to ../pokemon_sprites/train_starmie.png
# Fetching API data for '122' from https://pokeapi.co/api/v2/pokemon/122...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/122.png
# Downloading image...
# Successfully saved mr-mime sprite to ../pokemon_sprites/train_mr-mime.png
# Fetching API data for '123' from https://pokeapi.co/api/v2/pokemon/123...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/123.png
# Downloading image...
# Successfully saved scyther sprite to ../pokemon_sprites/train_scyther.png
# Fetching API data for '124' from https://pokeapi.co/api/v2/pokemon/124...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/124.png
# Downloading image...
# Successfully saved jynx sprite to ../pokemon_sprites/train_jynx.png
# Fetching API data for '125' from https://pokeapi.co/api/v2/pokemon/125...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/125.png
# Downloading image...
# Successfully saved electabuzz sprite to ../pokemon_sprites/train_electabuzz.png
# Fetching API data for '126' from https://pokeapi.co/api/v2/pokemon/126...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/126.png
# Downloading image...
# Successfully saved magmar sprite to ../pokemon_sprites/train_magmar.png
# Fetching API data for '127' from https://pokeapi.co/api/v2/pokemon/127...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/127.png
# Downloading image...
# Successfully saved pinsir sprite to ../pokemon_sprites/train_pinsir.png
# Fetching API data for '128' from https://pokeapi.co/api/v2/pokemon/128...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/128.png
# Downloading image...
# Successfully saved tauros sprite to ../pokemon_sprites/train_tauros.png
# Fetching API data for '129' from https://pokeapi.co/api/v2/pokemon/129...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/129.png
# Downloading image...
# Successfully saved magikarp sprite to ../pokemon_sprites/train_magikarp.png
# Fetching API data for '130' from https://pokeapi.co/api/v2/pokemon/130...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/130.png
# Downloading image...
# Successfully saved gyarados sprite to ../pokemon_sprites/train_gyarados.png
# Fetching API data for '131' from https://pokeapi.co/api/v2/pokemon/131...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/131.png
# Downloading image...
# Successfully saved lapras sprite to ../pokemon_sprites/train_lapras.png
# Fetching API data for '132' from https://pokeapi.co/api/v2/pokemon/132...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/132.png
# Downloading image...
# Successfully saved ditto sprite to ../pokemon_sprites/train_ditto.png
# Fetching API data for '133' from https://pokeapi.co/api/v2/pokemon/133...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/133.png
# Downloading image...
# Successfully saved eevee sprite to ../pokemon_sprites/train_eevee.png
# Fetching API data for '134' from https://pokeapi.co/api/v2/pokemon/134...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/134.png
# Downloading image...
# Successfully saved vaporeon sprite to ../pokemon_sprites/train_vaporeon.png
# Fetching API data for '135' from https://pokeapi.co/api/v2/pokemon/135...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/135.png
# Downloading image...
# Successfully saved jolteon sprite to ../pokemon_sprites/train_jolteon.png
# Fetching API data for '136' from https://pokeapi.co/api/v2/pokemon/136...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/136.png
# Downloading image...
# Successfully saved flareon sprite to ../pokemon_sprites/train_flareon.png
# Fetching API data for '137' from https://pokeapi.co/api/v2/pokemon/137...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/137.png
# Downloading image...
# Successfully saved porygon sprite to ../pokemon_sprites/train_porygon.png
# Fetching API data for '138' from https://pokeapi.co/api/v2/pokemon/138...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/138.png
# Downloading image...
# Successfully saved omanyte sprite to ../pokemon_sprites/train_omanyte.png
# Fetching API data for '139' from https://pokeapi.co/api/v2/pokemon/139...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/139.png
# Downloading image...
# Successfully saved omastar sprite to ../pokemon_sprites/train_omastar.png
# Fetching API data for '140' from https://pokeapi.co/api/v2/pokemon/140...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/140.png
# Downloading image...
# Successfully saved kabuto sprite to ../pokemon_sprites/train_kabuto.png
# Fetching API data for '141' from https://pokeapi.co/api/v2/pokemon/141...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/141.png
# Downloading image...
# Successfully saved kabutops sprite to ../pokemon_sprites/train_kabutops.png
# Fetching API data for '142' from https://pokeapi.co/api/v2/pokemon/142...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/142.png
# Downloading image...
# Successfully saved aerodactyl sprite to ../pokemon_sprites/train_aerodactyl.png
# Fetching API data for '143' from https://pokeapi.co/api/v2/pokemon/143...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/143.png
# Downloading image...
# Successfully saved snorlax sprite to ../pokemon_sprites/train_snorlax.png
# Fetching API data for '144' from https://pokeapi.co/api/v2/pokemon/144...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/144.png
# Downloading image...
# Successfully saved articuno sprite to ../pokemon_sprites/train_articuno.png
# Fetching API data for '145' from https://pokeapi.co/api/v2/pokemon/145...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/145.png
# Downloading image...
# Successfully saved zapdos sprite to ../pokemon_sprites/train_zapdos.png
# Fetching API data for '146' from https://pokeapi.co/api/v2/pokemon/146...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/146.png
# Downloading image...
# Successfully saved moltres sprite to ../pokemon_sprites/train_moltres.png
# Fetching API data for '147' from https://pokeapi.co/api/v2/pokemon/147...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/147.png
# Downloading image...
# Successfully saved dratini sprite to ../pokemon_sprites/train_dratini.png
# Fetching API data for '148' from https://pokeapi.co/api/v2/pokemon/148...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/148.png
# Downloading image...
# Successfully saved dragonair sprite to ../pokemon_sprites/train_dragonair.png
# Fetching API data for '149' from https://pokeapi.co/api/v2/pokemon/149...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/149.png
# Downloading image...
# Successfully saved dragonite sprite to ../pokemon_sprites/train_dragonite.png
# Fetching API data for '150' from https://pokeapi.co/api/v2/pokemon/150...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/150.png
# Downloading image...
# Successfully saved mewtwo sprite to ../pokemon_sprites/train_mewtwo.png
# Fetching API data for '151' from https://pokeapi.co/api/v2/pokemon/151...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/151.png
# Downloading image...
# Successfully saved mew sprite to ../pokemon_sprites/train_mew.png
# Fetching API data for '152' from https://pokeapi.co/api/v2/pokemon/152...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/152.png
# Downloading image...
# Successfully saved chikorita sprite to ../pokemon_sprites/train_chikorita.png
# Fetching API data for '153' from https://pokeapi.co/api/v2/pokemon/153...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/153.png
# Downloading image...
# Successfully saved bayleef sprite to ../pokemon_sprites/train_bayleef.png
# Fetching API data for '154' from https://pokeapi.co/api/v2/pokemon/154...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/154.png
# Downloading image...
# Successfully saved meganium sprite to ../pokemon_sprites/train_meganium.png
# Fetching API data for '155' from https://pokeapi.co/api/v2/pokemon/155...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/155.png
# Downloading image...
# Successfully saved cyndaquil sprite to ../pokemon_sprites/train_cyndaquil.png
# Fetching API data for '156' from https://pokeapi.co/api/v2/pokemon/156...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/156.png
# Downloading image...
# Successfully saved quilava sprite to ../pokemon_sprites/train_quilava.png
# Fetching API data for '157' from https://pokeapi.co/api/v2/pokemon/157...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/157.png
# Downloading image...
# Successfully saved typhlosion sprite to ../pokemon_sprites/train_typhlosion.png
# Fetching API data for '158' from https://pokeapi.co/api/v2/pokemon/158...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/158.png
# Downloading image...
# Successfully saved totodile sprite to ../pokemon_sprites/train_totodile.png
# Fetching API data for '159' from https://pokeapi.co/api/v2/pokemon/159...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/159.png
# Downloading image...
# Successfully saved croconaw sprite to ../pokemon_sprites/train_croconaw.png
# Fetching API data for '160' from https://pokeapi.co/api/v2/pokemon/160...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/160.png
# Downloading image...
# Successfully saved feraligatr sprite to ../pokemon_sprites/train_feraligatr.png
# Fetching API data for '161' from https://pokeapi.co/api/v2/pokemon/161...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/161.png
# Downloading image...
# Successfully saved sentret sprite to ../pokemon_sprites/train_sentret.png
# Fetching API data for '162' from https://pokeapi.co/api/v2/pokemon/162...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/162.png
# Downloading image...
# Successfully saved furret sprite to ../pokemon_sprites/train_furret.png
# Fetching API data for '163' from https://pokeapi.co/api/v2/pokemon/163...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/163.png
# Downloading image...
# Successfully saved hoothoot sprite to ../pokemon_sprites/train_hoothoot.png
# Fetching API data for '164' from https://pokeapi.co/api/v2/pokemon/164...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/164.png
# Downloading image...
# Successfully saved noctowl sprite to ../pokemon_sprites/train_noctowl.png
# Fetching API data for '165' from https://pokeapi.co/api/v2/pokemon/165...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/165.png
# Downloading image...
# Successfully saved ledyba sprite to ../pokemon_sprites/train_ledyba.png
# Fetching API data for '166' from https://pokeapi.co/api/v2/pokemon/166...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/166.png
# Downloading image...
# Successfully saved ledian sprite to ../pokemon_sprites/train_ledian.png
# Fetching API data for '167' from https://pokeapi.co/api/v2/pokemon/167...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/167.png
# Downloading image...
# Successfully saved spinarak sprite to ../pokemon_sprites/train_spinarak.png
# Fetching API data for '168' from https://pokeapi.co/api/v2/pokemon/168...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/168.png
# Downloading image...
# Successfully saved ariados sprite to ../pokemon_sprites/train_ariados.png
# Fetching API data for '169' from https://pokeapi.co/api/v2/pokemon/169...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/169.png
# Downloading image...
# Successfully saved crobat sprite to ../pokemon_sprites/train_crobat.png
# Fetching API data for '170' from https://pokeapi.co/api/v2/pokemon/170...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/170.png
# Downloading image...
# Successfully saved chinchou sprite to ../pokemon_sprites/train_chinchou.png
# Fetching API data for '171' from https://pokeapi.co/api/v2/pokemon/171...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/171.png
# Downloading image...
# Successfully saved lanturn sprite to ../pokemon_sprites/train_lanturn.png
# Fetching API data for '172' from https://pokeapi.co/api/v2/pokemon/172...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/172.png
# Downloading image...
# Successfully saved pichu sprite to ../pokemon_sprites/train_pichu.png
# Fetching API data for '173' from https://pokeapi.co/api/v2/pokemon/173...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/173.png
# Downloading image...
# Successfully saved cleffa sprite to ../pokemon_sprites/train_cleffa.png
# Fetching API data for '174' from https://pokeapi.co/api/v2/pokemon/174...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/174.png
# Downloading image...
# Successfully saved igglybuff sprite to ../pokemon_sprites/train_igglybuff.png
# Fetching API data for '175' from https://pokeapi.co/api/v2/pokemon/175...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/175.png
# Downloading image...
# Successfully saved togepi sprite to ../pokemon_sprites/train_togepi.png
# Fetching API data for '176' from https://pokeapi.co/api/v2/pokemon/176...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/176.png
# Downloading image...
# Successfully saved togetic sprite to ../pokemon_sprites/train_togetic.png
# Fetching API data for '177' from https://pokeapi.co/api/v2/pokemon/177...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/177.png
# Downloading image...
# Successfully saved natu sprite to ../pokemon_sprites/train_natu.png
# Fetching API data for '178' from https://pokeapi.co/api/v2/pokemon/178...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/178.png
# Downloading image...
# Successfully saved xatu sprite to ../pokemon_sprites/train_xatu.png
# Fetching API data for '179' from https://pokeapi.co/api/v2/pokemon/179...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/179.png
# Downloading image...
# Successfully saved mareep sprite to ../pokemon_sprites/train_mareep.png
# Fetching API data for '180' from https://pokeapi.co/api/v2/pokemon/180...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/180.png
# Downloading image...
# Successfully saved flaaffy sprite to ../pokemon_sprites/train_flaaffy.png
# Fetching API data for '181' from https://pokeapi.co/api/v2/pokemon/181...
# ...
# Downloading image...
# Successfully saved cyclizar sprite to ../pokemon_sprites/train_cyclizar.png
# Fetching API data for '968' from https://pokeapi.co/api/v2/pokemon/968...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/968.png
# Downloading image...
# Successfully saved orthworm sprite to ../pokemon_sprites/train_orthworm.png
# Fetching API data for '969' from https://pokeapi.co/api/v2/pokemon/969...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/969.png
# Downloading image...
# Successfully saved glimmet sprite to ../pokemon_sprites/train_glimmet.png
# Fetching API data for '970' from https://pokeapi.co/api/v2/pokemon/970...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/970.png
# Downloading image...
# Successfully saved glimmora sprite to ../pokemon_sprites/train_glimmora.png
# Fetching API data for '971' from https://pokeapi.co/api/v2/pokemon/971...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/971.png
# Downloading image...
# Successfully saved greavard sprite to ../pokemon_sprites/train_greavard.png
# Fetching API data for '972' from https://pokeapi.co/api/v2/pokemon/972...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/972.png
# Downloading image...
# Successfully saved houndstone sprite to ../pokemon_sprites/train_houndstone.png
# Fetching API data for '973' from https://pokeapi.co/api/v2/pokemon/973...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/973.png
# Downloading image...
# Successfully saved flamigo sprite to ../pokemon_sprites/train_flamigo.png
# Fetching API data for '974' from https://pokeapi.co/api/v2/pokemon/974...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/974.png
# Downloading image...
# Successfully saved cetoddle sprite to ../pokemon_sprites/train_cetoddle.png
# Fetching API data for '975' from https://pokeapi.co/api/v2/pokemon/975...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/975.png
# Downloading image...
# Successfully saved cetitan sprite to ../pokemon_sprites/train_cetitan.png
# Fetching API data for '976' from https://pokeapi.co/api/v2/pokemon/976...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/976.png
# Downloading image...
# Successfully saved veluza sprite to ../pokemon_sprites/train_veluza.png
# Fetching API data for '977' from https://pokeapi.co/api/v2/pokemon/977...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/977.png
# Downloading image...
# Successfully saved dondozo sprite to ../pokemon_sprites/train_dondozo.png
# Fetching API data for '978' from https://pokeapi.co/api/v2/pokemon/978...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/978.png
# Downloading image...
# Successfully saved tatsugiri-curly sprite to ../pokemon_sprites/train_tatsugiri-curly.png
# Fetching API data for '979' from https://pokeapi.co/api/v2/pokemon/979...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/979.png
# Downloading image...
# Successfully saved annihilape sprite to ../pokemon_sprites/train_annihilape.png
# Fetching API data for '980' from https://pokeapi.co/api/v2/pokemon/980...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/980.png
# Downloading image...
# Successfully saved clodsire sprite to ../pokemon_sprites/train_clodsire.png
# Fetching API data for '981' from https://pokeapi.co/api/v2/pokemon/981...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/981.png
# Downloading image...
# Successfully saved farigiraf sprite to ../pokemon_sprites/train_farigiraf.png
# Fetching API data for '982' from https://pokeapi.co/api/v2/pokemon/982...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/982.png
# Downloading image...
# Successfully saved dudunsparce-two-segment sprite to ../pokemon_sprites/train_dudunsparce-two-segment.png
# Fetching API data for '983' from https://pokeapi.co/api/v2/pokemon/983...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/983.png
# Downloading image...
# Successfully saved kingambit sprite to ../pokemon_sprites/train_kingambit.png
# Fetching API data for '984' from https://pokeapi.co/api/v2/pokemon/984...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/984.png
# Downloading image...
# Successfully saved great-tusk sprite to ../pokemon_sprites/train_great-tusk.png
# Fetching API data for '985' from https://pokeapi.co/api/v2/pokemon/985...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/985.png
# Downloading image...
# Successfully saved scream-tail sprite to ../pokemon_sprites/train_scream-tail.png
# Fetching API data for '986' from https://pokeapi.co/api/v2/pokemon/986...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/986.png
# Downloading image...
# Successfully saved brute-bonnet sprite to ../pokemon_sprites/train_brute-bonnet.png
# Fetching API data for '987' from https://pokeapi.co/api/v2/pokemon/987...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/987.png
# Downloading image...
# Successfully saved flutter-mane sprite to ../pokemon_sprites/train_flutter-mane.png
# Fetching API data for '988' from https://pokeapi.co/api/v2/pokemon/988...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/988.png
# Downloading image...
# Successfully saved slither-wing sprite to ../pokemon_sprites/train_slither-wing.png
# Fetching API data for '989' from https://pokeapi.co/api/v2/pokemon/989...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/989.png
# Downloading image...
# Successfully saved sandy-shocks sprite to ../pokemon_sprites/train_sandy-shocks.png
# Fetching API data for '990' from https://pokeapi.co/api/v2/pokemon/990...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/990.png
# Downloading image...
# Successfully saved iron-treads sprite to ../pokemon_sprites/train_iron-treads.png
# Fetching API data for '991' from https://pokeapi.co/api/v2/pokemon/991...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/991.png
# Downloading image...
# Successfully saved iron-bundle sprite to ../pokemon_sprites/train_iron-bundle.png
# Fetching API data for '992' from https://pokeapi.co/api/v2/pokemon/992...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/992.png
# Downloading image...
# Successfully saved iron-hands sprite to ../pokemon_sprites/train_iron-hands.png
# Fetching API data for '993' from https://pokeapi.co/api/v2/pokemon/993...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/993.png
# Downloading image...
# Successfully saved iron-jugulis sprite to ../pokemon_sprites/train_iron-jugulis.png
# Fetching API data for '994' from https://pokeapi.co/api/v2/pokemon/994...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/994.png
# Downloading image...
# Successfully saved iron-moth sprite to ../pokemon_sprites/train_iron-moth.png
# Fetching API data for '995' from https://pokeapi.co/api/v2/pokemon/995...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/995.png
# Downloading image...
# Successfully saved iron-thorns sprite to ../pokemon_sprites/train_iron-thorns.png
# Fetching API data for '996' from https://pokeapi.co/api/v2/pokemon/996...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/996.png
# Downloading image...
# Successfully saved frigibax sprite to ../pokemon_sprites/train_frigibax.png
# Fetching API data for '997' from https://pokeapi.co/api/v2/pokemon/997...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/997.png
# Downloading image...
# Successfully saved arctibax sprite to ../pokemon_sprites/train_arctibax.png
# Fetching API data for '998' from https://pokeapi.co/api/v2/pokemon/998...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/998.png
# Downloading image...
# Successfully saved baxcalibur sprite to ../pokemon_sprites/train_baxcalibur.png
# Fetching API data for '999' from https://pokeapi.co/api/v2/pokemon/999...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/999.png
# Downloading image...
# Successfully saved gimmighoul sprite to ../pokemon_sprites/train_gimmighoul.png
# Fetching API data for '1000' from https://pokeapi.co/api/v2/pokemon/1000...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/1000.png
# Downloading image...
# Successfully saved gholdengo sprite to ../pokemon_sprites/train_gholdengo.png
# Fetching API data for '1001' from https://pokeapi.co/api/v2/pokemon/1001...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/1001.png
# Downloading image...
# Successfully saved wo-chien sprite to ../pokemon_sprites/train_wo-chien.png
# Fetching API data for '1002' from https://pokeapi.co/api/v2/pokemon/1002...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/1002.png
# Downloading image...
# Successfully saved chien-pao sprite to ../pokemon_sprites/train_chien-pao.png
# Fetching API data for '1003' from https://pokeapi.co/api/v2/pokemon/1003...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/1003.png
# Downloading image...
# Successfully saved ting-lu sprite to ../pokemon_sprites/train_ting-lu.png
# Fetching API data for '1004' from https://pokeapi.co/api/v2/pokemon/1004...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/1004.png
# Downloading image...
# Successfully saved chi-yu sprite to ../pokemon_sprites/train_chi-yu.png
# Fetching API data for '1005' from https://pokeapi.co/api/v2/pokemon/1005...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/1005.png
# Downloading image...
# Successfully saved roaring-moon sprite to ../pokemon_sprites/train_roaring-moon.png
# Fetching API data for '1006' from https://pokeapi.co/api/v2/pokemon/1006...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/1006.png
# Downloading image...
# Successfully saved iron-valiant sprite to ../pokemon_sprites/train_iron-valiant.png
# Fetching API data for '1007' from https://pokeapi.co/api/v2/pokemon/1007...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/1007.png
# Downloading image...
# Successfully saved koraidon sprite to ../pokemon_sprites/train_koraidon.png
# Fetching API data for '1008' from https://pokeapi.co/api/v2/pokemon/1008...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/1008.png
# Downloading image...
# Successfully saved miraidon sprite to ../pokemon_sprites/train_miraidon.png
# Fetching API data for '1009' from https://pokeapi.co/api/v2/pokemon/1009...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/1009.png
# Downloading image...
# Successfully saved walking-wake sprite to ../pokemon_sprites/train_walking-wake.png
# Fetching API data for '1010' from https://pokeapi.co/api/v2/pokemon/1010...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/1010.png
# Downloading image...
# Successfully saved iron-leaves sprite to ../pokemon_sprites/train_iron-leaves.png
# Fetching API data for '1011' from https://pokeapi.co/api/v2/pokemon/1011...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/1011.png
# Downloading image...
# Successfully saved dipplin sprite to ../pokemon_sprites/train_dipplin.png
# Fetching API data for '1012' from https://pokeapi.co/api/v2/pokemon/1012...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/1012.png
# Downloading image...
# Successfully saved poltchageist sprite to ../pokemon_sprites/train_poltchageist.png
# Fetching API data for '1013' from https://pokeapi.co/api/v2/pokemon/1013...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/1013.png
# Downloading image...
# Successfully saved sinistcha sprite to ../pokemon_sprites/train_sinistcha.png
# Fetching API data for '1014' from https://pokeapi.co/api/v2/pokemon/1014...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/1014.png
# Downloading image...
# Successfully saved okidogi sprite to ../pokemon_sprites/train_okidogi.png
# Fetching API data for '1015' from https://pokeapi.co/api/v2/pokemon/1015...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/1015.png
# Downloading image...
# Successfully saved munkidori sprite to ../pokemon_sprites/train_munkidori.png
# Fetching API data for '1016' from https://pokeapi.co/api/v2/pokemon/1016...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/1016.png
# Downloading image...
# Successfully saved fezandipiti sprite to ../pokemon_sprites/train_fezandipiti.png
# Fetching API data for '1017' from https://pokeapi.co/api/v2/pokemon/1017...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/1017.png
# Downloading image...
# Successfully saved ogerpon sprite to ../pokemon_sprites/train_ogerpon.png
# Fetching API data for '1018' from https://pokeapi.co/api/v2/pokemon/1018...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/1018.png
# Downloading image...
# Successfully saved archaludon sprite to ../pokemon_sprites/train_archaludon.png
# Fetching API data for '1019' from https://pokeapi.co/api/v2/pokemon/1019...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/1019.png
# Downloading image...
# Successfully saved hydrapple sprite to ../pokemon_sprites/train_hydrapple.png
# Fetching API data for '1020' from https://pokeapi.co/api/v2/pokemon/1020...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/1020.png
# Downloading image...
# Successfully saved gouging-fire sprite to ../pokemon_sprites/train_gouging-fire.png
# Fetching API data for '1021' from https://pokeapi.co/api/v2/pokemon/1021...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/1021.png
# Downloading image...
# Successfully saved raging-bolt sprite to ../pokemon_sprites/train_raging-bolt.png
# Fetching API data for '1022' from https://pokeapi.co/api/v2/pokemon/1022...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/1022.png
# Downloading image...
# Successfully saved iron-boulder sprite to ../pokemon_sprites/train_iron-boulder.png
# Fetching API data for '1023' from https://pokeapi.co/api/v2/pokemon/1023...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/1023.png
# Downloading image...
# Successfully saved iron-crown sprite to ../pokemon_sprites/train_iron-crown.png
# Fetching API data for '1024' from https://pokeapi.co/api/v2/pokemon/1024...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/1024.png
# Downloading image...
# Successfully saved terapagos sprite to ../pokemon_sprites/train_terapagos.png
# Fetching API data for '1025' from https://pokeapi.co/api/v2/pokemon/1025...
# Sprite found at: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/1025.png
# Downloading image...
# Successfully saved pecharunt sprite to ../pokemon_sprites/train_pecharunt.png
